# %% [markdown]
# <a href="https://colab.research.google.com/github/husam6101/Food-Detection-Recognition-and-Ingredient-Allergy-Detection/blob/main/Food_Detection%2C_Regocnition%2C_and_Ingredient_Allergy_Prediction_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Food Detection, Regocnition, and Ingredient-Allergy Prediction with YOLOv5, ResNet, and XGBoost Fine-Tuning**
# **Project by:** Husam Shamseddine and Roy Zoghbi

# %%
#@title Mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# @title Imports
# TensorFlow and Keras
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, LSTM, Embedding
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing import image as keras_image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.text import Tokenizer

# Other ML and data processing libraries
import pandas as pd
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Other libraries
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os
import subprocess
import glob
import math

# %% [markdown]
# ## **Args Definition and Initialization**

# %%
# @markdown # **Defining Args Class**
# @markdown For easier control over hyperparameters and training settings
# @markdown ## **Parameters**
# @markdown - `resnet_batch_size`: Batch size for the ResNet model
# @markdown - `resnet_learning_rate`: Learning rate for the resnet model
# @markdown - `resnet_epochs`: Number of epochs for the resnet model
# @markdown - `resnet_split`: Validation:Training split for the resnet model
# @markdown - `resnet_number_of_classes`: Number of classes that ResNet is being trained on,
# @markdown calculated automatically from the dataset
# @markdown - `resnet_model_path`: Save file path for ResNet
# @markdown - `yolov5_path`: Save file path for YOLOv5
# @markdown - `xgboost_batch_size`: Batch size for the XGBoost Model
# @markdown - `xgboost_learning_rate`: Learning rate for the XGBoost model
# @markdown - `xgboost_n_estimators`: Number of estimators for the XGBoost model
# @markdown - `xgboost_max_depth`: Mad depth parameter for the XGBoost model
# @markdown - `xgboost_split`: Validation:Training split for the XGBoost model
# @markdown - `xgboost_random_state`: Random state parameter for the data going into the XGBoost model
# @markdown - `xgboost_model_location`; Save file path for XGBoost


class Args:
  def __init__(
      self,
      resnet_batch_size,
      resnet_learning_rate,
      resnet_epochs,
      resnet_split,
      resnet_model_path,
      yolov5_path,
      xgboost_n_estimators,
      xgboost_learning_rate,
      xgboost_max_depth,
      xgboost_split,
      xgboost_random_state,
      xgboost_model_path
  ):
    self.resnet_batch_size = resnet_batch_size
    self.resnet_learning_rate = resnet_learning_rate
    self.resnet_epochs = resnet_epochs
    self.resnet_split = resnet_split
    self.resnet_model_path = resnet_model_path
    self.yolov5_path = yolov5_path
    self.xgboost_n_estimators = xgboost_n_estimators
    self.xgboost_learning_rate = xgboost_learning_rate
    self.xgboost_max_depth = xgboost_max_depth
    self.xgboost_split = xgboost_split
    self.xgboost_random_state = xgboost_random_state
    self.xgboost_model_path = xgboost_model_path

    self.resnet_number_of_classes = None

# %%
# @markdown # **Initializing Default Args**
# @markdown ## **ResNet For Object Recognition**
resnet_batch_size = 32 # @param {type:"integer"}
resnet_learning_rate = 0.0002 # @param {type:"number"}
resnet_epochs = 20 # @param {type:"integer"}
resnet_split = 0.2 # @param {type:"number"}
resnet_model_path = "/content/drive/MyDrive/project/final/ResNet_best.h5" # @param {type:"string"}
# @markdown ## **YOLOv5 for Food Object Detection**
yolov5_path = "/content/drive/MyDrive/project/final/" # @param {type:"string"}
# @markdown ## **XGBoost for Ingredient and Allergy Prediction**
xgboost_n_estimators = 100 # @param {type:"integer"}
xgboost_learning_rate = 0.05 # @param {type:"number"}
xgboost_max_depth = 4 # @param {type:"integer"}
xgboost_split = 0.2 # @param {type:"number"}
xgboost_random_state = 42 # @param {type:"integer"}
xgboost_model_path = "/content/drive/MyDrive/project/final/XGBoost_best.h5" # @param {type:"string"}

args = Args(
    resnet_batch_size = resnet_batch_size,
    resnet_learning_rate = resnet_learning_rate,
    resnet_epochs = resnet_epochs,
    resnet_split = resnet_split,
    resnet_model_path = resnet_model_path,
    yolov5_path = yolov5_path,
    xgboost_n_estimators = xgboost_n_estimators,
    xgboost_learning_rate = xgboost_learning_rate,
    xgboost_max_depth = xgboost_max_depth,
    xgboost_split = xgboost_split,
    xgboost_random_state = xgboost_random_state,
    xgboost_model_path = xgboost_model_path,
)

# deleting variables to avoid propagating them global beyond this cell
del resnet_batch_size
del resnet_learning_rate
del resnet_epochs
del resnet_split
del resnet_model_path
del yolov5_path
del xgboost_n_estimators
del xgboost_learning_rate
del xgboost_max_depth
del xgboost_split
del xgboost_random_state
del xgboost_model_path

# %% [markdown]
# ## **YOLOv5**

# %% [markdown]
# ### **Cloning and Pre-Treating Data**

# %%
# @markdown ## **Get Food Detection Data for YOLOv5**
# %cd /content/
# !gdown https://drive.google.com/uc?id=1vKfBWxTTu2Bcvu-MofBw4GMDsPK8AukH
# Out:
# /content
# Downloading...
# From: https://drive.google.com/uc?id=1vKfBWxTTu2Bcvu-MofBw4GMDsPK8AukH
# To: /content/OID.zip
# 100% 976M/976M [00:14<00:00, 68.2MB/s]

# %%
# @markdown ## **Extract the Data from the .zip File**
# %cd /content/
# !unzip -o "/content/OID.zip" -d '/content/OID'

# %%
# @markdown # **Treating Issues with OID Data**
# @markdown The downloaded and extracted OID data is missing its data.yaml file,
# @markdown therefore it would required to modify all label .txt files to set their class to `0`,
# @markdown and create a data.yaml file for the `food` class for detection
# @markdown ## **Process**
# @markdown 1. **Modify text files for `train_coco` and `val_coco`:** Loop through all text files and set the first part of every line,
# @markdown   that refers to the class to `0`
# @markdown 2. **Change directory names:** of `train_coco`` and `val_coco` to `train` and `valid`
def modify_text_files(folder_path):
    for filename in os.listdir(folder_path):
        if filename.endswith('.txt'):  # Check if it's a text file
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r') as file:
                lines = file.readlines()

            with open(file_path, 'w') as file:
                for line in lines:
                    if line.strip():  # Check if the line is not empty
                        file.write('0 ' + line[1:])
                    else:
                        file.write(line)

def change_folder_name(old_name, new_name):
    try:
        os.rename(old_name, new_name)
        print(f"Folder renamed from {old_name} to {new_name}")
    except OSError as e:
        print(f"Error: {e.strerror}")

modify_text_files('/content/OID/OID/labels/train_coco/')
modify_text_files('/content/OID/OID/labels/val_coco/')
change_folder_name('/content/OID/OID/labels/train_coco/', '/content/OID/OID/labels/train/')
change_folder_name('/content/OID/OID/labels/val_coco/', '/content/OID/OID/labels/valid/')
# Out:
# Folder renamed from /content/OID/OID/labels/train_coco/ to /content/OID/OID/labels/train/
# Folder renamed from /content/OID/OID/labels/val_coco/ to /content/OID/OID/labels/valid/

# %%
# @markdown # **Create data.yaml**
# @markdown Create a data.yaml file and fill it as follows:
# @markdown > train: /content/OID/OID/images/train<br>
# @markdown > val: /content/OID/OID/images/valid<br><br>
# @markdown > nc: 1<br>
# @markdown > names: ['food']
print('Creating data.yaml...')
with open('/content/OID/OID/data.yaml', 'w') as config_file:
    config_file.write("train: /content/OID/OID/images/train\n")
    config_file.write("val: /content/OID/OID/images/valid\n\n")
    config_file.write("nc: 1\n")
    config_file.write("names: ['food']\n")

print('Finished.')
# Out:
# Creating data.yaml...
# Finished.

# %% [markdown]
# ### **Cloning, Training, and Testing of YOLOv5**

# %%
# @markdown ## **Clone YOLOv5 and Install Requirements**
# @markdown > Note: Often times does Colab requires a restart of the runtime
# @markdown after installing the requirements,
# @markdown and rerunning past cells becomes necessary for volatile imports, and definitions
# %cd {args.yolov5_path}
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/project/final
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16094, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 16094 (delta 0), reused 4 (delta 0), pack-reused 16089
# Receiving objects: 100% (16094/16094), 14.76 MiB | 14.12 MiB/s, done.
# Resolving deltas: 100% (11024/11024), done.
# /content/drive/MyDrive/project/final/yolov5
# Collecting gitpython>=3.1.30 (from -r requirements.txt (line 5))
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 6)) (3.7.1)
# Requirement already satisfied: numpy>=1.22.2 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 7)) (1.23.5)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 8)) (4.8.0.76)
# Collecting Pillow>=10.0.1 (from -r requirements.txt (line 9))
#   Downloading Pillow-10.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 24.9 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 11)) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 12)) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 13)) (1.11.4)
# Collecting thop>=0.1.1 (from -r requirements.txt (line 14))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 15)) (2.1.0+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 16)) (0.16.0+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 17)) (4.66.1)
# Collecting ultralytics>=8.0.147 (from -r requirements.txt (line 18))
#   Downloading ultralytics-8.0.227-py3-none-any.whl (660 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.5/660.5 kB 41.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 27)) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 28)) (0.12.2)
# Requirement already satisfied: setuptools>=65.5.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 42)) (67.7.2)
# Collecting gitdb<5,>=4.0.1 (from gitpython>=3.1.30->-r requirements.txt (line 5))
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (2023.11.17)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2.1.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.0.147->-r requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.3.post1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5))
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Installing collected packages: smmap, Pillow, gitdb, thop, gitpython, ultralytics
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.1.0 which is incompatible.
# Successfully installed Pillow-10.1.0 gitdb-4.0.11 gitpython-3.1.40 smmap-5.0.1 thop-0.1.1.post2209072238 ultralytics-8.0.227

# %%
# %cd /content/drive/MyDrive/project/final/yolov5
# !pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/project/final/yolov5
# Requirement already satisfied: gitpython>=3.1.30 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 5)) (3.1.40)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 6)) (3.7.1)
# Requirement already satisfied: numpy>=1.22.2 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 7)) (1.23.5)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 8)) (4.8.0.76)
# Requirement already satisfied: Pillow>=10.0.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 9)) (10.1.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 11)) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 12)) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 13)) (1.11.4)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 15)) (2.1.0+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 16)) (0.16.0+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 17)) (4.66.1)
# Requirement already satisfied: ultralytics>=8.0.147 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 18)) (8.0.227)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 27)) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 28)) (0.12.2)
# Requirement already satisfied: setuptools>=65.5.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 42)) (67.7.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.11)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (2023.11.17)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2.1.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.0.147->-r requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.3.post1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)

# %%
# @markdown # **Train Yolov5**
# @markdown Train yolo on the previously treated OID data for food detection
# @markdown > Note: Some warnings may appear due to corrupt image data,
# @markdown > but the remaining, uncorrupted data is still more than enough to get a good result
# %cd {args.yolov5_path + '/yolov5'}
# !python train.py --img 640 --batch 16 --epochs 10 --data '/content/OID/OID/data.yaml' --weights yolov5s.pt --cache
# Out:
# Streaming output truncated to the last 5000 lines.
# train: WARNING ⚠️ /content/OID/OID/images/train/1e471d2892f7f7f2_jpg.rf.cc8aca203e7e4181c1f10d176ac2baa7.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e47c15ab422b0ce_jpg.rf.1cc49a90277dde06bcbae91a4485e748.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e4b65ed1c08ea2a_jpg.rf.ac337b39533452e29612eaa8e5bf2ef4.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e4b84506ef2009a_jpg.rf.4c569fbc9fb949a3d8bc8aef4fa9b554.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e4e305d64b51ccd_jpg.rf.b5a674f104599b69a2d470b0418503e8.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e501b237bc35f91_jpg.rf.71b024b6a82c73a99f38511c3c6d0269.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e51e06a262c7707_jpg.rf.83a76eb5b2adad2bd3271a0ab504495e.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e551c9f2f4bb7a3_jpg.rf.5c109d1ac14b547d5d5aac66204328db.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e5706c7ecee85a8_jpg.rf.e24bc51930f53e65159717bf15b052c2.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e57cf26a7547f55_jpg.rf.2d7a6aff4fbb0e36dbbd73cf039b3d56.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e596f89b7bf951c_jpg.rf.43e3351fa326ddbf77c4bd7c3baf7013.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e5bb1a7cf6bccd3_jpg.rf.f4e016debdbec247a33b27d28a78b0d9.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e624c2265b0bfbb_jpg.rf.7c8093bbc7152abcd1f4bb63d8db9072.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e6261c3e674fbc4_jpg.rf.3158bf5721d1c4644f8cf129e3ecb635.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e634cdbbb48410f_jpg.rf.b820da3d851545764121bdd42df0262a.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e64784ed59eb835_jpg.rf.25ba29fa0a1f153f78fbf3f23e5d69a2.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e6524ae9e9127ca_jpg.rf.09f2f9fc4338dacf09ce76f7a3989453.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e6690476365bcf9_jpg.rf.7e82d6051a28777ecabb3f0487e0601d.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e6a2c363a2072e7_jpg.rf.c44a1da9cf64fbb44aa626cd84df1384.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e6e3f3c9c1e8688_jpg.rf.79c596f07469c07d6d41a96f276afb6d.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e74caf0769d5044_jpg.rf.8d4b358e660d211a9588e8d1e1d87c2e.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e76d24ffa7efd94_jpg.rf.3148a537bda89f5b1b47b4dd664a9a11.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e787f27d4e8e04d_jpg.rf.95c6690868501e01f58c07d695079cb3.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e7c6da54b4b5ce3_jpg.rf.e93abf5a3e23f94f089d1d553470a1e4.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e8239408cf09d42_jpg.rf.9d648effcc00fc9da703a9bac8ed3d4c.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e8306cf7c6bd235_jpg.rf.1e8dfe2076ce306de79706af47e6f4bb.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e83bb3103926450_jpg.rf.3aea0b47c4734ba6631a72fb04541dae.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e842f586306b664_jpg.rf.d97241d5de3353596da09e5d2e66fe2d.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e8430f0141e096c_jpg.rf.b39100c145aaa9f6d977d61812fed7fd.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e8623afd0d38863_jpg.rf.e1a5ecc9b558b652825b1727db18460c.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e8c0d99fa1af75f_jpg.rf.4d69e8450c9d326c1df698f90e24c6c7.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e8d82297ee2155d_jpg.rf.9b0a80004a7eb39c68c024ad721d2b94.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e8f0eddb38f4e89_jpg.rf.41e8e82015a3d476e93be64aaee7c8ec.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e8f0eddb38f4e89_jpg.rf.7dfbdb701f77229e766fba2cb4a7f448.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e95cb113f8e1c9e_jpg.rf.75d8a05e8c453c3f29f57b511d57d8b6.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e95cb113f8e1c9e_jpg.rf.b09a26438c5d5b9a4558b63a746da85b.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e9a87ee05256fac_jpg.rf.fb8bd7f56e7dec6cc8c5112d371266a3.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e9b854dc4ea9672_jpg.rf.5f7a2f4fe66dd4ccd64d70c7eab189ce.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1e9c208feb636f76_jpg.rf.20f0ec2599065a968326d842f5b481c5.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ea08737696f8246_jpg.rf.142844f1e86601dbe718714d871a028b.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ea47aded3326e64_jpg.rf.1238b1c927d332273ef794f8fdd90d43.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ea8e4034ee2e6ec_jpg.rf.d66540c8a6e2e43a2700db7d619a1797.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1eae5c3cf4c304e5_jpg.rf.21d1a3c08f99d5b734e6d9308f2baa52.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ebd3df1902d045a_jpg.rf.1be7ce29c801f3312e97d82762287208.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ebd3df1902d045a_jpg.rf.2f838e6baf4b9ad00461d65f3cb4f613.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ec0c057a20d0095_jpg.rf.f2a0bcf77ad18b671703171275f060b1.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ec94c2625c849b6_jpg.rf.277ac7567f0c66054e7c94ce9b23e30c.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ec9865d779b83bd_jpg.rf.86dccb83ea05fffb637906ce6678996b.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ed16f39722b47ee_jpg.rf.3b62f7c1c91b5f9332dd6f1d0bb290ec.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ed2971a26f0b589_jpg.rf.aea9732de1e66def3d7279c5d1c90293.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ed6f5f30757a7fa_jpg.rf.449e2b8dd688997d22cb9519591be741.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1edaba26a20d3b47_jpg.rf.20d9319c35b24a4d7e4217dfd260e7e0.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ee0d85c6d350d47_jpg.rf.80dae3ea6f56c1f6e98b2db0b226f69c.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ee4687ffd974d29_jpg.rf.c0aa5fe628196fbf0ea8c01cca092acf.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1eecef1fa6e1a5db_jpg.rf.c97989b1068969f15d3a6cbaeb7351d7.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1eefbf5440b20ffb_jpg.rf.c3f68630a2719b4fa8bf8fd3f1f1922c.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ef1fcc301d8cf8b_jpg.rf.8e339263cd9a0e09e57f16f5ea2031a2.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ef3cdb14b9ffc8a_jpg.rf.242791df8468f25a97116b402e59d481.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ef588eac97b4915_jpg.rf.3f592d3e4d70236669c9c8ad71c3da67.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ef90ab177803a5b_jpg.rf.79c2e43c05ea1a9724e7f928edcd5194.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f00606a0362bdef_jpg.rf.7c6164e856e37fb435a7bafa3e52d7dd.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f03506d6e40718b_jpg.rf.3d576983b9171900d71129109656a84e.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f04a0bba45314f8_jpg.rf.43125eaf493e055c0dccc59a8958a326.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f0cb40493b48517_jpg.rf.54c5e248c32a50c486d12963bdc36458.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f0cb40493b48517_jpg.rf.e55d25e0bcafb593868290f79726696a.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f111cddeca3c8c4_jpg.rf.2e55c1f997db08b5b05eee83d4e2da65.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f11f687ca2dafb6_jpg.rf.eb1c83afe3d0196b7919231f8ee93fec.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f12a6c763959697_jpg.rf.404216024d059debd848107a13319db3.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f140eb42d020fab_jpg.rf.b05d50de176286bf54ae3adef3b248ee.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f15b06291140489_jpg.rf.d24f04d939a313dd06c76265789932fd.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f1655d076c57c1d_jpg.rf.96264e2de860f1991072112de4ab28a2.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f1a35f33fa6a3ca_jpg.rf.dfa907f9edf172baac5bb3add045a5fd.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f1d2d0c8bb69e6b_jpg.rf.01e1656dc027a6d74dc714caeb1d57b4.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f219c9864ecbfab_jpg.rf.69def9e8696bf29466cb09c0960ae216.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f22300d35941907_jpg.rf.7897f076534118de98e06e718f6cf99e.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f28f8e679fc3308_jpg.rf.a5002eb7f5b894c09460a3015835148f.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f2bebe24d635fe0_jpg.rf.cfd4a042b49cbe608ac867efb91acfbc.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f2c56cc2b5a604a_jpg.rf.0abcb14407755adffe8b15b5389c236f.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f3165f47ce90e05_jpg.rf.51af42fcc77b1f93a873b85ad641aecc.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f3542ae9f5362ea_jpg.rf.cb0c147d8e9621841c9cf953f2e07755.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f399ef9dc93419e_jpg.rf.9e43f2bf096425315e71b3eea21ef38f.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f3ede5f1909dfa1_jpg.rf.907394ff9a051ad5f2fb9d4ef556d208.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f4177c3675b4da9_jpg.rf.f3c1598730fea129e6deedbedad86fb4.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f41e3c65d9a92cd_jpg.rf.19cada5c6de63b85ec30f6ff7a13130b.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f48c7c82f4ea4b0_jpg.rf.f572e27ca9ec5a3144c1abc6a011b618.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f4b9bef4c69f5e9_jpg.rf.2627fb72d1ab12044167b624a1e7baec.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f4d75f136192acf_jpg.rf.a6584789f4c00fa58904d94e71c0a02b.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f5021cd70c15c41_jpg.rf.10a098b5d424287d245c293d6a4c0a03.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f58d66b63b54933_jpg.rf.835737e8259e47f6419d3542504ffb00.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f6234f731154c58_jpg.rf.91d108bc9e111e610756ace23503656c.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f66c536df18379d_jpg.rf.9be86d96e7257cee6086d56b96fa94d2.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f68d00beb29b700_jpg.rf.10383a3849959e3c14f5255946aa6cc5.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f6adc91c1a0d421_jpg.rf.24920a36ad54a81b48bf722151e8d4a8.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f6beb7bb7e70436_jpg.rf.f0bbcccc51ca2d9b5b80176d1ed4404a.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f6d7f60fa5cd436_jpg.rf.49be8387e5c3ccfba78bcdb7416569b5.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f6fe05915d06eee_jpg.rf.e924696ed1987d32fba28aaf1c88edf2.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f70ce7ed292a511_jpg.rf.fb81712d344a87b5506c86f5fef777f6.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f711da33b40e53f_jpg.rf.40369f131c131c34a5b48fa6cfe9ba42.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f75822395b6526c_jpg.rf.ce2181327bcbb73ad29107a92c1d78de.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f761e7db3a4f34b_jpg.rf.526893dff97a068b0941f0c3d0e0e043.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f7c367a8f8a2d54_jpg.rf.87402edc30db96d7b5939e194b939d41.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f8314c51d8c018e_jpg.rf.f3d5255e7bed5188f2847da56568af2d.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f84de9d05a8e74b_jpg.rf.11283ab100dde8febc40126a3643e960.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f8546cc204d0e63_jpg.rf.dd8e0bcc0cadf53776b0718aded042e0.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f89034238c72e8f_jpg.rf.b65b8807e806cd00f2bcad0f52b7503b.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f97edf223bca179_jpg.rf.ee438d872d498120844661db5128409b.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1f9de03b8cb2a7f9_jpg.rf.c93de96cd906cddd0726f335c1ae9e91.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fa0ae90596712d3_jpg.rf.1d74276f1761626b06118603ecc23d99.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fa53a4ea9fde8b7_jpg.rf.7ae47e9225df7e204e3fd174ea0f6461.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fa579ac07ba2fb8_jpg.rf.745718cd626100c0ef1baf572997baca.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fbb11a8a0a9116c_jpg.rf.01f89cb96fc7d9b57a66fc06483c355d.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fbb11a8a0a9116c_jpg.rf.7da4ead9586c52776ebdd23c9a198b28.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fbe21b68da9fae8_jpg.rf.0f9d2cadab05d12c2855b25bd8809142.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fc05c733461f151_jpg.rf.f3f6a5fe38198963c648ab54f26b75ea.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fc33b6d81a9ea87_jpg.rf.0e0f558ee0d5779c3dbc6b5f03d0b508.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fc569d676e029e2_jpg.rf.cdbad64eb69b0b6b64c9166fd011de94.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fc5ffd504b7b66e_jpg.rf.e99aae35032ff0e5670371e630bde64e.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fc719550389ee29_jpg.rf.ad52994d360c516ea9fa06c8d944ad4e.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fc7652ec4f62e98_jpg.rf.f92d9fa733aab75a7d9a3091e6cbc326.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fc96abc95bc220b_jpg.rf.8e053fde07c40690093616eee58deb02.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fce3fcff0900727_jpg.rf.f1d0e9c0b0feeef8d9383c73f4b2522f.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fd03470b09e56e2_jpg.rf.e674d8e63dec6be46e1772d16f89e876.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fd068f1706679de_jpg.rf.ef9be5c5582e12885e6e7a4b5874c8d1.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fd1a7c1c6f4dd58_jpg.rf.d94455489cb2512dfe62063142990b18.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fd2bde451b9b491_jpg.rf.30914200210e37f01ef5eb2a87444fa8.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fd5cdd4a7e3afa5_jpg.rf.a5aa16756a3d57dbd580b9f5be2413a1.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fdcddf2dbf3adf0_jpg.rf.490ccd77c954c7f1e2dc7a6d018fb836.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fe0f79fc05a0bee_jpg.rf.f0de9cb2db12655cff9b48d8df6a0995.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fef2dedb6c943ce_jpg.rf.0011f74dd20493afd76cb850a8b59ace.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1fef2dedb6c943ce_jpg.rf.111db35d84b895e11d302f1091628f0d.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ff0a355f31b42b4_jpg.rf.f8a8aee081a6c85f6790bdf1a3f49ac5.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ff24de9fd5bd776_jpg.rf.64cb8becdc3c0173d18d2b59814a7727.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ff39b0de63f2646_jpg.rf.65d8a0cf37ff2d7fb2e5c1aa55607b97.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ff491aa726de945_jpg.rf.f18b72c958ffcbc8d286f8f78b3b8da9.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ffbed88b8253849_jpg.rf.51c69b11e7a33b00732073f2d33d9fb8.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/1ffcb8e3f163a335_jpg.rf.686c58228c8117ba06d4cf974a9a6174.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2000af9112dac65b_jpg.rf.6568a50545dedce95ac344cc86648ef8.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/200bba1fb3c5cab4_jpg.rf.ffb10fa2944eae91f58e5988275a4e11.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/200c4e91a130f514_jpg.rf.18ecbf3e6869caba6454932807987b08.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/200e54d7852a87c5_jpg.rf.33498ab2678e959a4433daf73f1cac87.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/200f49162e4eae70_jpg.rf.7207cf67b3e36f55f48d2bb336086cfa.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/201786442667f5df_jpg.rf.189230ff563c4522498e2ffbe451ac67.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20186cb62310ed71_jpg.rf.32f848a431c48a45b8151b3a76d07788.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/201ff2181304e06e_jpg.rf.d08d2583fd9156268b8c2dcf1edb4635.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2020504fdc8ad8f0_jpg.rf.1b1fe3a1aa059bf2f5ffed13231ddbda.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2026785eec354d9f_jpg.rf.5582bfe43abd4128cfcb9ccbd694546f.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/202c33d955c365d9_jpg.rf.71a104bc3a842150f26e1cda5930d770.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/203162e622e1d4ae_jpg.rf.5d0956e205d60aca21e2fe5e865f4264.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/203874116baf58b0_jpg.rf.d87665dcfad76d9467c813790a0f01cc.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/203b57d4524d6f87_jpg.rf.fc6f24db62986637dd6bd5064d177252.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/203ea52a6fa27728_jpg.rf.470137bf2357ba12888e87c3a11aca38.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/204342d7e24a3478_jpg.rf.5d4579231e563e80605e29b5bd301a6c.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/204555d3f456f186_jpg.rf.5ae8db763a6db21be3e188b403259c62.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/204555d3f456f186_jpg.rf.e85bd1c23a1af7ebe59dab40f266c90d.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2048fe857e5434d0_jpg.rf.ffdcc698d61f3bab2569c47e932c7727.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/204c2c346c4b08ce_jpg.rf.6274d2d91f82927a1628cfd4a62477a4.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/204da75739da3f91_jpg.rf.5849128a7d76baabcac735c4215c139c.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/204ebab35f42eacb_jpg.rf.97c3696c954958fe65b33b0c7b1e2334.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2051d6e1912b7504_jpg.rf.f4eb5df6d6cac7e3f036c3d7e4f41db1.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20529c62e726fad2_jpg.rf.d42cb589d2313a5f52b1d9adaefecfe8.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20544203ea81e8ec_jpg.rf.d0647f695dc1483bad1e8e1e6dce3c83.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20558d790b1ef6fb_jpg.rf.6ec2fe52b9f1d76a22546cee571444a9.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/205607c3b9d9ab3f_jpg.rf.1286c83e2ab3f2e26de3152ab88ca784.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2056ebaf55980683_jpg.rf.4937c668608af1b4bb2da742d93aac68.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2058903a5b9bc723_jpg.rf.7823c68f0e4cdbbc2f6331d9c26ea9b6.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2059208c0b163ddd_jpg.rf.139bf8f80dd511d73271ea377b2174c1.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20685dadf8dd9ab5_jpg.rf.5da3871cacb2c67f4572df6c6cc9ea62.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/206bba960dc8ac8b_jpg.rf.d8621dd9f8ed390d65ec11561a0e12d3.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/206e561b34f552a7_jpg.rf.c2490c6a76e589e2fa2b3520e1ee5092.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20726efc28f189d3_jpg.rf.0ca56bb517378b324969d67be6ea5310.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2072b8a7a32712b8_jpg.rf.dda58ac77337657e85e246f28becdfcd.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20757c542a24c5ce_jpg.rf.b8b0015da59fc9f8ccb4e8bd02b2e602.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2079828d96ce458c_jpg.rf.a8137fee12cbe1f5b829e8fe8639a492.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/207f3fcb4826f1dc_jpg.rf.5b59139f5ce10b3a60b4357e278a9948.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2087cd16b29033f0_jpg.rf.8a6cbe781796081822e6348b8d3bed2e.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/208a346a100278b9_jpg.rf.4f0f5c8d14a0c91d85dde4447898e37b.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/208ee70a1609657c_jpg.rf.a4a74d48a63be22a47794c068306c6f7.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20957d60e8b23928_jpg.rf.a2cf16dce01b7fc9fb69ceb8cf167f01.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2097bdb2f8ef7860_jpg.rf.a9c413da61050d13a12143a297d5b3d9.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2097bdb2f8ef7860_jpg.rf.c0336922b499c6c2b3c7b7eaaa8b4f00.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/209b7f2cac721a85_jpg.rf.d3b943d51a00dafeb495552cbab5a348.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/209ef9b752f0c605_jpg.rf.a152be0ced05be693b406ea9670439d6.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20a0d5ef8c4e0f01_jpg.rf.6b43634ba8ec600b224f484ce786a291.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20ab9a8f4bfc55e7_jpg.rf.0d868867b66a4bacca829e82b6c5d890.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20ad3dcba1319f5d_jpg.rf.933d4a9025fee70ece92578e4788445a.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20ad6a2df9ec2957_jpg.rf.d5abaf6b8281baacd9e7f535d0ba3a80.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20ae6c05bd6db20b_jpg.rf.5bad0c94d843d6a1f9e6cc72b1dfd9e7.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20aff231dba27490_jpg.rf.6e4c70a4a01851344feeba0986294302.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20b2f560f0c4ef6b_jpg.rf.d4012093be4e8a70d63123fc370a5bc9.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20b78b320808d5ee_jpg.rf.5725ff31e79973829ae3b9048434511b.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20b933ce71b15300_jpg.rf.8e4b3ae856c73e8aacda71f9b36827ba.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20ba20598ae12ca3_jpg.rf.41bcea50dc4e3b119430fafe43f76965.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20c1028d30ca1e23_jpg.rf.014b95728d31607eb646fd466c26e809.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20ca58f8f4e2a231_jpg.rf.d6a31e0ce3149f448c922d9b8788b707.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20cb910b51b1a07b_jpg.rf.367dfc451b23292cb32095ae68878e91.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20d115b597f302b0_jpg.rf.55aa29e6f4dabbb3c1202612e15e543b.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20d32e349433ee8f_jpg.rf.ec986caf9997936066a7ed53db0ea7f6.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20d4226ee89eb59c_jpg.rf.91223555441bb62aa120e86c0afd1a1b.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20d72f5b0ca59dc3_jpg.rf.eaf693ab6866df80781338edc04e57c9.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20d7ede073e5f4a8_jpg.rf.ffb704ecfedf5ee8e62460cfc088b305.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20d98cec2775f021_jpg.rf.5332e5b9da78b4d96dc81d04dd4c0fa1.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20dbbf0ef5e7d437_jpg.rf.30dc5fdd66ebb72297f7b7ae41b96f28.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20e3ea9da0d9ad47_jpg.rf.bb041bed90c0b0a0395806f2c683996e.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20e3ea9da0d9ad47_jpg.rf.eb08aad8ec47a3c761bce94671660d30.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20e7f98da22c5b78_jpg.rf.86c04b9ab35a844a253f2fa5a94bdbff.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20ea39ef8b992b97_jpg.rf.2f22a5dda14503070e9e4269f13eb0a8.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20f0800d4b4e43a8_jpg.rf.018903800c28c4472e25ebc14530ca1d.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20f6d838a6018e53_jpg.rf.f447583aca9cfe835d5fa8931a061875.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20fb48e0f256882b_jpg.rf.50e3e81d35742d40095c88e5ea2fd0a8.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/20ffa2803a61375c_jpg.rf.77a36611dc9a4b90f63a7691aebe0872.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/21003ef0d91a0d81_jpg.rf.01cdaecb1d3da6be84d7a70fd7de286d.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2100d08649b179fd_jpg.rf.0461843cdc27060023472bbb2c1c893f.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2101728138b86237_jpg.rf.f27590bc7201463449b05f2c6c8db043.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2103a9584a9dff13_jpg.rf.55d909656eb1cc53fbc51ae85b075102.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/21123d064952e3ef_jpg.rf.1a3a5567a1fc53b514190efda7c5e701.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2115ea1c56cf8172_jpg.rf.01c45cafe8beb62cd7f099d61f456f48.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2119d0bf6d91aba8_jpg.rf.8bcf3271cf14fce95878823c5349643d.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2119d0bf6d91aba8_jpg.rf.f7c503f18af03abb5c1f59c6ebf26a83.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2122434410a8ca57_jpg.rf.00607d01e7270ebee0c736b45948686d.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2122434410a8ca57_jpg.rf.0c362706a31b7aef060ee3761d04b961.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2122b2c4031ba233_jpg.rf.5c03c170280713077e431ff417f71410.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/212391911cf30707_jpg.rf.4305529982c5e052b179479d03ac64ec.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2125934f5167b6b2_jpg.rf.4b649f49de88bb5859690fc459b74b3f.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/212e9af10c3c5c29_jpg.rf.1842ac21e2a3a3aef9366a69a6b6c8a0.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/212f29ce83ba711b_jpg.rf.3871cdf656049d9ba5cc7a2a53d848bb.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/21337e88e3516569_jpg.rf.06c6e3a2023b404c0991307c69c97921.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2135877616033a80_jpg.rf.9cb7afc55fa68b2203b142a1764872ff.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2136fc72751b8516_jpg.rf.5098107ae74a1c39c843735e3a78f7cc.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/21373173f3ecd829_jpg.rf.72ffc94215d0aceb100aeff461021960.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/213976076b1a9f94_jpg.rf.1268a5e2362e98864a289f396b6fda28.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/213aeb8e4ed006b5_jpg.rf.414b63042af7426452f099e76c3b6a74.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/213c62bd7383c023_jpg.rf.021d2c6e69db840357e1d4575be36f7b.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/214384ef62e02598_jpg.rf.7cc8e656c6b2b4c1a8a3201524f878f5.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2148fd1cc074c6d9_jpg.rf.295722a4b50f4acc057643b90597fe1b.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/214d270da56de56e_jpg.rf.bdeb72d93a04852d977c4564b2eec99a.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/214f02355defe3c0_jpg.rf.f3e013e59a7a514e4bcd63e74ed1c422.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/214fe814be3416d6_jpg.rf.34dd7e370a0128e810bb1f85afbe534f.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2150839b1cfd7d71_jpg.rf.962035f5fb9b72333769c5bdb763986b.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/21535167afcf0c68_jpg.rf.4dec5da504f3496e5b670c276f40afc8.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/21583d2757525804_jpg.rf.3aaf2c28cdbc34e0c58e6a912f25970f.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/215ca87a6ee7da6d_jpg.rf.bf737f9197eec8b479076e28276dff95.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/216128bf45d11d68_jpg.rf.cd096aa08ced6eb14ab9a0a12efc0986.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/216661ca5e9fe33d_jpg.rf.e08a036ed8b281f8ffe245b0c4ee6e2b.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/21680ccc93c7f7c9_jpg.rf.8a57345f4cba29c0a57ad058e14239a5.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/216e344c8db2c7f3_jpg.rf.32f4ebe323598280bda4e8fc207c6149.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/217921071b341c0d_jpg.rf.4da29a86a9815ee1a8d1d9448d38b6c4.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/217b0688972a8035_jpg.rf.2b767479faa9142d28e3ceae9b97ade0.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/217fb2060cee15a4_jpg.rf.5248e544477a6d7f9f0972b906782328.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/217fc7413e0fcdee_jpg.rf.b03cb20ba21dd99d03b06a0b96305bb3.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/217fe235e5f1a7bf_jpg.rf.2d0018c6c79d918dacc751404961f6ed.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/218256453026d79d_jpg.rf.1b05eb9a6150666671c32072b87741eb.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2184b5296ede7f86_jpg.rf.6863806436eacd8195c6cbf6b6452cd0.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/21860c579650082b_jpg.rf.ba9d193ca2f0572dea0ca3dc661e8991.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/21879f0c3053581e_jpg.rf.2423dc4d9bef892b59da2e2c93c2832a.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2187dfbc8fa8ca33_jpg.rf.de6e0baa9b96eb110473a3f2d39ca020.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/218a3c28c0108336_jpg.rf.97afd031fecd476042c3ff09e97d2789.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/218fcffaa8cf5f34_jpg.rf.98818f07d997df72670afb87b7892b7e.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/2192a7b4299e5be6_jpg.rf.64c959aa920257d82b79b26b31486634.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# train: WARNING ⚠️ /content/OID/OID/images/train/21987094358c0e9e_jpg.rf.df844718737e6c136a6768a970468897.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# ...
# val: WARNING ⚠️ /content/OID/OID/images/valid/fbb278b9f5494e20_jpg.rf.b6d1a3c69b9eb45caf45de9808b345ca.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fbdcf4a7d65ca8ee_jpg.rf.36b65caedaa5f9013a0f3a1920671a03.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fbeb9e4ec98c39c5_jpg.rf.e0fe2e4989bafbc28340163e84420e4e.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fbee7b6e279a986f_jpg.rf.0d80c3a1ca7da46a6502c67451491ac8.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fbef2f9176f55c9c_jpg.rf.bfbaa029caaf68d3355309ccbbe56ea3.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fbf2d7fce87405c0_jpg.rf.af4794b0c68f7f9311ea372f49764898.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fbfa380da52a9866_jpg.rf.e10ea4002a597400e76a164338792ece.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fc061b726fdeb154_jpg.rf.9ade1628c4f52b3be638fb74d8e732a4.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fc1a8de39b30c7bf_jpg.rf.d0edcd92e20b56a88836159431cbe605.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fc1f1074860fccd8_jpg.rf.6cbc673920ccaaa16e052113aeb1532f.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fc3922afaeffe0b1_jpg.rf.4c0e9eebfd5a9779d91925e79018cf76.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fc3e849ed9df4478_jpg.rf.85279e299ec85fb4992d8d447ba2338e.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fc3f4d8765a100b8_jpg.rf.22d5b3f11e0dbac167fe0ae941094a8d.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fc6c0f373d8341cd_jpg.rf.04b5b07ed1e1d89cfa2abdc5282739e9.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fc8971756f9ec194_jpg.rf.3a8fe0e88409e251dbc681dc1d47623e.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fcd058726af06ad5_jpg.rf.d4ba186b600075040c2ad2b62b541f28.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fcdcdfa19ed6046e_jpg.rf.5f02f116e53a4088f157376294e210cc.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fd02933846a88d1d_jpg.rf.be827d38469d470b8bab290aeaaa9d21.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fd034c9e929e5294_jpg.rf.3b6834a153e7fb03f06a246f1fb39f04.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fd3d5cd8965f3452_jpg.rf.8a7f1ccdd0d2c1ad35bfe97292222876.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fd429c370dd00f20_jpg.rf.0b38b2d5f882835a47cdb96a759d59bc.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fd5d4d5a264922fe_jpg.rf.681db061a44c633cd75c983263921116.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fd7e02e0ca1e34e5_jpg.rf.8cc0c849575a93ea7754e144f3c69272.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fd93550c9678deaa_jpg.rf.0e7ba4332961f19e3f44e00961467ae4.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fd975afc5fad69e8_jpg.rf.2de536eb27ef5fdd970129ec0053b2ad.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fdddf52d12456b8a_jpg.rf.888cece442f992471c8b4f7b7aeb8fac.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fded1ebef56608a4_jpg.rf.649e52ce22fa7f6f1388c94ef19dafa3.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fdfecd9542689e03_jpg.rf.3c4f0a7a03a1d3d3d0e11c5e9720d91f.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fe171f8c87a60ad9_jpg.rf.deba906f1a7beff88332f8c5c595a21b.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fe34e2a6d1b58606_jpg.rf.fa72684d36badea556f898e61c7b2e73.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fe545aa31a3144d5_jpg.rf.6c9293d785edc627bbb4cab551d6484e.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fe5a594fc139faba_jpg.rf.b9ab9518459b30c514ddaa92cc9af0a2.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fe7a6cc5d3407fa8_jpg.rf.178f71167e240198755b253d0d350f06.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fea20db9efadd7a1_jpg.rf.45db16d1979aeec492af0ef37737b770.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fead530e1185e705_jpg.rf.8d72f7abac93008572a6a19c0915312e.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/ff3ed6f26d3bf26c_jpg.rf.71e98c5026beed7d226639ad1caeba00.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/ff52c706fa53ca9b_jpg.rf.211a55123dece224886b15de75f2c49f.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/ff5f4e7e918e09f3_jpg.rf.428d7a4d718ecc1fc126629b056689cb.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/ff622fde4dc1e422_jpg.rf.1cdde6a724d91c4b4814be05800139c4.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/ff8327b7a1661713_jpg.rf.f652a81c61ddeef5a52997f8d7b467e5.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/ff88049e61f0f4ef_jpg.rf.0f86b1e161cda4b1c6c9bf78e463835d.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/ff8dc18cd098fa35_jpg.rf.eee6b3534514a9acf50036b8fb7d698f.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/ff99ede5e3b2a126_jpg.rf.ca15d575c554ad31b68e559aa96352c7.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/ffac222bf51d7c0c_jpg.rf.bf124bbf4b2e391e26bf4300d6be86ec.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/ffbebe0b55ec3a63_jpg.rf.ddc667abcf6b787170431c0072067cda.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/ffc6b6ca3ff64eb7_jpg.rf.d56199d84fa914ba229c4cc2c726ef87.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/ffd0539029931078_jpg.rf.130cb2c63d5283da6c78336f3370df2f.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/ffe5f835bb62fed4_jpg.rf.9c20e790abf153bde5f2480a389cc05c.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/fffb7682786160a7_jpg.rf.49e59f4767dacd9b83ded8fcdfdb1b85.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/imag21.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/image(0004).jpeg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/image(0006).jpeg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/image(0017).jpeg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/image(0031).jpeg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/image(0053).jpeg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/image(0057).jpeg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/image(0064).jpeg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/image(0076).jpeg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/image(0084).jpeg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/image39.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/image43.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: WARNING ⚠️ /content/OID/OID/images/valid/image45.jpg: ignoring corrupt image/label: labels require 5 columns, 6 columns detected
# val: New cache created: /content/OID/OID/labels/valid.cache
# val: Caching images (0.7GB ram): 100% 590/590 [00:02<00:00, 212.61it/s]
#
# AutoAnchor: 3.76 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 10 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         0/9      3.46G     0.0853    0.03633          0          9        640: 100% 146/146 [00:56<00:00,  2.57it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:10<00:00,  1.82it/s]
#                    all        590       1441      0.394       0.42       0.35      0.149
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         1/9      4.27G    0.05563    0.03426          0          9        640: 100% 146/146 [00:50<00:00,  2.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:07<00:00,  2.44it/s]
#                    all        590       1441      0.429      0.457      0.381      0.183
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         2/9      4.27G    0.05045    0.03399          0         11        640: 100% 146/146 [00:50<00:00,  2.88it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:07<00:00,  2.52it/s]
#                    all        590       1441      0.481       0.43      0.412      0.218
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         3/9      4.27G    0.04658    0.03261          0          8        640: 100% 146/146 [00:57<00:00,  2.52it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:07<00:00,  2.39it/s]
#                    all        590       1441      0.505      0.458      0.426      0.239
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         4/9      4.27G    0.04329    0.03362          0          8        640: 100% 146/146 [00:51<00:00,  2.83it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:09<00:00,  2.03it/s]
#                    all        590       1441      0.493      0.461      0.417      0.237
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         5/9      4.27G    0.04067    0.03222          0          5        640: 100% 146/146 [00:48<00:00,  3.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:08<00:00,  2.23it/s]
#                    all        590       1441       0.49      0.514      0.473      0.286
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         6/9      4.27G    0.03919    0.03227          0          3        640: 100% 146/146 [00:49<00:00,  2.93it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:07<00:00,  2.60it/s]
#                    all        590       1441      0.466      0.438      0.416       0.25
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         7/9      4.27G    0.03792    0.03159          0         34        640: 100% 146/146 [00:51<00:00,  2.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:07<00:00,  2.64it/s]
#                    all        590       1441      0.528      0.541      0.504      0.318
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         8/9      4.27G    0.03661     0.0306          0          8        640: 100% 146/146 [00:50<00:00,  2.87it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:09<00:00,  2.09it/s]
#                    all        590       1441      0.544      0.523      0.493      0.308
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         9/9      4.27G    0.03467    0.03019          0         17        640: 100% 146/146 [00:49<00:00,  2.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:08<00:00,  2.30it/s]
#                    all        590       1441      0.552      0.523      0.494      0.314
#
# 10 epochs completed in 0.170 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 14.4MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:11<00:00,  1.72it/s]
#                    all        590       1441      0.526      0.541      0.504      0.318
# Results saved to runs/train/exp

# %%
# @title **Test YOLOv5**
# @markdown # **Test YOLOv5**
# @markdown Test yolo on an image
# @markdown > Test cells is currently commented for the sake of a smoother-running process
# %cd {args.yolov5_path + yolov5}
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source "/content/apple-pie.png" --save-txt

# %% [markdown]
# ## **ResNet50**

# %% [markdown]
# ### **Kaggle Setup**

# %%
# @markdown # **Setup kaggle.json**
# @markdown > Upload **Kaggle.json** in */content/* then run
import os

# Create a Kaggle folder
os.makedirs('/root/.kaggle', exist_ok=True)

# Move the kaggle.json file
# %cd /content/
# !mv kaggle.json /root/.kaggle/
# Set permissions
# !chmod 600 /root/.kaggle/kaggle.json
# Out:
# /content
# mv: cannot stat 'kaggle.json': No such file or directory

# %%
# @markdown # **Download Data from Kaggle**
# @markdown Download and unzip the **food101tiny** from Kaggle in <u>*/content*</u>
# %cd /content/
# !kaggle datasets download -d msarmi9/food101tiny -p /content/
# unzipping contents of .zip dataset
# !unzip "/content/food101tiny.zip" -d '/content/food101tiny'
# Out:
# /content
# food101tiny.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  /content/food101tiny.zip
# replace /content/food101tiny/data/food-101-tiny/train/apple_pie/1005649.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# ### **ResNet Setup and Preprocessing**

# %%
# @markdown # **Loading Data from Directories + Augmentation**
# @markdown ## **Dataset Directory Parameters**
train_dir = '/content/food101tiny/data/food-101-tiny/train' # @param {type: "string"}
test_dir = '/content/food101tiny/data/food-101-tiny/valid' # @param {type: "string"}

# @markdown ## **Data Augmentation Parameters**
rotation_range = 20 #@param {type: "integer"}
width_shift_range = 0.2 #@param (type: "number")
height_shift_range = 0.2 #@param {type: "number"}
shear_range = 0.2 #@param {type: "number"}
zoom_range = 0.2 #@param {type: "number"}
horizontal_flip = True #@param {type: "boolean"}

# @markdown ## **Process**
# @markdown Load data and perform data augmentation using `ImageDataGenerator`
# @markdown as well as split the data through to `train_generator` and `validation_generator`
# @markdown where the `target_size` is appropriately set to `(224,224)` for ResNet fine-tuning

# Define the data augmentation and preprocessing
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range = rotation_range,
    width_shift_range = width_shift_range,
    height_shift_range = height_shift_range,
    shear_range = shear_range,
    zoom_range = zoom_range,
    horizontal_flip = horizontal_flip,
    fill_mode = 'nearest',
    validation_split = args.resnet_split
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (224, 224),
    batch_size = args.resnet_batch_size,
    class_mode = 'categorical',
    subset = 'training'
)

validation_generator = train_datagen.flow_from_directory(
    test_dir,
    target_size = (224, 224),
    batch_size = args.resnet_batch_size,
    class_mode = 'categorical',
    subset = 'validation'
)

del train_dir
del test_dir
del rotation_range
del width_shift_range
del height_shift_range
del shear_range
del zoom_range
del horizontal_flip
# Out:
# Found 1200 images belonging to 10 classes.
# Found 100 images belonging to 10 classes.

# %%
# @markdown # **Getting Class Number and Treating Labels**
# @markdown ## **Process**
# @markdown First, extract the number of classes as well as `class_labels` from `train_generator` (`validation_generator` would work too)
# @markdown then replace the underscores in `class_labels` with a space

args.resnet_number_of_classes = len(train_generator.class_indices)

# Getting class labels
class_indices = train_generator.class_indices
class_labels = [label.replace('_', ' ') for label in class_indices.keys()]
class_labels.sort(key=lambda label: class_indices[label.replace(' ', '_')])

print(f'Number of classes: {args.resnet_number_of_classes}')
print(f'Labels: {class_labels}')
# Out:
# Number of classes: 10
# Labels: ['apple pie', 'bibimbap', 'cannoli', 'edamame', 'falafel', 'french toast', 'ice cream', 'ramen', 'sushi', 'tiramisu']

# %% [markdown]
# ### **Training and Testing Fine-Tuned ResNet Model**

# %%
# @title Fine-Tune the Layers
# @markdown # **Finetune ResNet Layers**
# @markdown ## **Process**
# @markdown 1. Load the ResNet50 model pre-trained on ImageNet data
# @markdown 2. Freeze the layers in the base model
# @markdown 3. Add the layers:
# @markdown   1. `GlobalAveragePooling2D` to the top layer
# @markdown   2. A fully connected `Dense` layer with `ReLU` activation
# @markdown   3. A logistic `Dense` layer for the previously extracted `args.resnet_number_of_classes`
# @markdown     that will serve as an output
# @markdown 4. Compile the model
# @markdown
# @markdown
# @markdown > Note: The model uses `categorical_crossentropy` as a loss function
# @markdown and keeps track of `accuracy` in its metrics

base_model = ResNet50(weights = 'imagenet', include_top = False)
for layer in base_model.layers:
    layer.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation = 'relu')(x)
predictions = Dense(args.resnet_number_of_classes, activation = 'softmax')(x)

model = Model(inputs = base_model.input, outputs = predictions)
model.summary()
model.compile(
    optimizer = Adam(learning_rate = args.resnet_learning_rate),
    loss = 'categorical_crossentropy',
    metrics = ['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]      0         []
#
#  conv1_pad (ZeroPadding2D)   (None, None, None, 3)        0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, None, None, 64)       9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, None, None, 64)       256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, None, None, 64)       0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, None, None, 64)       0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, None, None, 64)       0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, None, None, 64)       4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, None, None, 64)       256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, None, None, 64)       0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, None, None, 64)       36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, None, None, 64)       256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, None, None, 64)       0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, None, None, 256)      16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, None, None, 256)      16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, None, None, 256)      1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, None, None, 256)      1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, None, None, 256)      0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, None, None, 256)      0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, None, None, 64)       16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, None, None, 64)       256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, None, None, 64)       0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, None, None, 64)       36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, None, None, 64)       256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, None, None, 64)       0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, None, None, 256)      16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, None, None, 256)      1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, None, None, 256)      0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, None, None, 256)      0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, None, None, 64)       16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, None, None, 64)       256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, None, None, 64)       0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, None, None, 64)       36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, None, None, 64)       256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, None, None, 64)       0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, None, None, 256)      16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, None, None, 256)      1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, None, None, 256)      0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, None, None, 256)      0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, None, None, 128)      32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, None, None, 128)      512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, None, None, 128)      0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, None, None, 128)      147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, None, None, 128)      512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, None, None, 128)      0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, None, None, 512)      131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, None, None, 512)      66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, None, None, 512)      2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, None, None, 512)      2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, None, None, 512)      0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, None, None, 512)      0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, None, None, 128)      65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, None, None, 128)      512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, None, None, 128)      0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, None, None, 128)      147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, None, None, 128)      512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, None, None, 128)      0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, None, None, 512)      66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, None, None, 512)      2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, None, None, 512)      0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, None, None, 512)      0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, None, None, 128)      65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, None, None, 128)      512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, None, None, 128)      0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, None, None, 128)      147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, None, None, 128)      512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, None, None, 128)      0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, None, None, 512)      66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, None, None, 512)      2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, None, None, 512)      0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, None, None, 512)      0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, None, None, 128)      65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, None, None, 128)      512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, None, None, 128)      0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, None, None, 128)      147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, None, None, 128)      512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, None, None, 128)      0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, None, None, 512)      66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, None, None, 512)      2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, None, None, 512)      0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, None, None, 512)      0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, None, None, 256)      131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, None, None, 256)      1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, None, None, 256)      0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, None, None, 256)      590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, None, None, 256)      1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, None, None, 256)      0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, None, None, 1024)     525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, None, None, 1024)     263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, None, None, 1024)     4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, None, None, 1024)     4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, None, None, 1024)     0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, None, None, 1024)     0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, None, None, 256)      262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, None, None, 256)      1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, None, None, 256)      0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, None, None, 256)      590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, None, None, 256)      1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, None, None, 256)      0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, None, None, 1024)     263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, None, None, 1024)     4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, None, None, 1024)     0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, None, None, 1024)     0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, None, None, 256)      262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, None, None, 256)      1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, None, None, 256)      0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, None, None, 256)      590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, None, None, 256)      1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, None, None, 256)      0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, None, None, 1024)     263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, None, None, 1024)     4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, None, None, 1024)     0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, None, None, 1024)     0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, None, None, 256)      262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, None, None, 256)      1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, None, None, 256)      0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, None, None, 256)      590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, None, None, 256)      1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, None, None, 256)      0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, None, None, 1024)     263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, None, None, 1024)     4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, None, None, 1024)     0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, None, None, 1024)     0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, None, None, 256)      262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, None, None, 256)      1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, None, None, 256)      0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, None, None, 256)      590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, None, None, 256)      1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, None, None, 256)      0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, None, None, 1024)     263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, None, None, 1024)     4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, None, None, 1024)     0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, None, None, 1024)     0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, None, None, 256)      262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, None, None, 256)      1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, None, None, 256)      0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, None, None, 256)      590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, None, None, 256)      1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, None, None, 256)      0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, None, None, 1024)     263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, None, None, 1024)     4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, None, None, 1024)     0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, None, None, 1024)     0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, None, None, 512)      524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, None, None, 512)      2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, None, None, 512)      0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, None, None, 512)      2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, None, None, 512)      2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, None, None, 512)      0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, None, None, 2048)     2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, None, None, 2048)     1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, None, None, 2048)     8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, None, None, 2048)     8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, None, None, 2048)     0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, None, None, 2048)     0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, None, None, 512)      1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, None, None, 512)      2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, None, None, 512)      0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, None, None, 512)      2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, None, None, 512)      2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, None, None, 512)      0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, None, None, 2048)     1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, None, None, 2048)     8192      ['conv5_block2_3_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, None, None, 2048)     0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activati  (None, None, None, 2048)     0         ['conv5_block2_add[0][0]']
#  on)
#
#  conv5_block3_1_conv (Conv2  (None, None, None, 512)      1049088   ['conv5_block2_out[0][0]']
#  D)
#
#  conv5_block3_1_bn (BatchNo  (None, None, None, 512)      2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_relu (Activ  (None, None, None, 512)      0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_conv (Conv2  (None, None, None, 512)      2359808   ['conv5_block3_1_relu[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, None, None, 512)      2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, None, None, 512)      0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, None, None, 2048)     1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, None, None, 2048)     8192      ['conv5_block3_3_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, None, None, 2048)     0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activati  (None, None, None, 2048)     0         ['conv5_block3_add[0][0]']
#  on)
#
#  global_average_pooling2d (  (None, 2048)                 0         ['conv5_block3_out[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)                 2098176   ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense_1 (Dense)             (None, 10)                   10250     ['dense[0][0]']
#
# ==================================================================================================
# Total params: 25696138 (98.02 MB)
# Trainable params: 2108426 (8.04 MB)
# Non-trainable params: 23587712 (89.98 MB)
# __________________________________________________________________________________________________

# %%
# @title Train the Model
# @markdown ## **Training the model**
checkpoint_path = args.resnet_model_path
# @markdown ## **Process**

# @markdown 1. Implementing checkpointing for best model with `ModelCheckpoint`
# @markdown   > Note that the checkpoint monitors `val_accuracy` in `max` mode
# @markdown     and that `save_best_only` is set to `True`
# @markdown
# @markdown
# @markdown 2. Calculate the values of `steps_per_epoch` and `validation_steps` based on (samples / batch_size)
# @markdown 3. Train the model

checkpoint = ModelCheckpoint(
    checkpoint_path,
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True,
    mode='max'
)

steps_per_epoch = math.ceil(train_generator.samples / train_generator.batch_size)
validation_steps = math.ceil(validation_generator.samples / validation_generator.batch_size)

history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    validation_data=validation_generator,
    validation_steps=validation_steps,
    epochs=args.resnet_epochs,
    callbacks = [checkpoint])
# Out:
# Epoch 1/20
# 38/38 [==============================] - ETA: 0s - loss: 1.4430 - accuracy: 0.5058
# Epoch 1: val_accuracy improved from -inf to 0.71000, saving model to /content/drive/MyDrive/project/final/ResNet_best.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 38/38 [==============================] - 36s 608ms/step - loss: 1.4430 - accuracy: 0.5058 - val_loss: 0.8989 - val_accuracy: 0.7100
# Epoch 2/20
# 38/38 [==============================] - ETA: 0s - loss: 0.6803 - accuracy: 0.7825
# Epoch 2: val_accuracy improved from 0.71000 to 0.75000, saving model to /content/drive/MyDrive/project/final/ResNet_best.h5
# 38/38 [==============================] - 23s 613ms/step - loss: 0.6803 - accuracy: 0.7825 - val_loss: 0.7396 - val_accuracy: 0.7500
# Epoch 3/20
# 38/38 [==============================] - ETA: 0s - loss: 0.5109 - accuracy: 0.8350
# Epoch 3: val_accuracy improved from 0.75000 to 0.77000, saving model to /content/drive/MyDrive/project/final/ResNet_best.h5
# 38/38 [==============================] - 27s 726ms/step - loss: 0.5109 - accuracy: 0.8350 - val_loss: 0.6851 - val_accuracy: 0.7700
# Epoch 4/20
# 38/38 [==============================] - ETA: 0s - loss: 0.4356 - accuracy: 0.8533
# Epoch 4: val_accuracy did not improve from 0.77000
# 38/38 [==============================] - 22s 574ms/step - loss: 0.4356 - accuracy: 0.8533 - val_loss: 0.7144 - val_accuracy: 0.7400
# Epoch 5/20
# 38/38 [==============================] - ETA: 0s - loss: 0.3582 - accuracy: 0.8925
# Epoch 5: val_accuracy did not improve from 0.77000
# 38/38 [==============================] - 22s 584ms/step - loss: 0.3582 - accuracy: 0.8925 - val_loss: 0.6599 - val_accuracy: 0.7600
# Epoch 6/20
# 38/38 [==============================] - ETA: 0s - loss: 0.2894 - accuracy: 0.9125
# Epoch 6: val_accuracy improved from 0.77000 to 0.79000, saving model to /content/drive/MyDrive/project/final/ResNet_best.h5
# 38/38 [==============================] - 23s 608ms/step - loss: 0.2894 - accuracy: 0.9125 - val_loss: 0.6428 - val_accuracy: 0.7900
# Epoch 7/20
# 38/38 [==============================] - ETA: 0s - loss: 0.2426 - accuracy: 0.9233
# Epoch 7: val_accuracy improved from 0.79000 to 0.81000, saving model to /content/drive/MyDrive/project/final/ResNet_best.h5
# 38/38 [==============================] - 26s 686ms/step - loss: 0.2426 - accuracy: 0.9233 - val_loss: 0.5508 - val_accuracy: 0.8100
# Epoch 8/20
# 38/38 [==============================] - ETA: 0s - loss: 0.2098 - accuracy: 0.9383
# Epoch 8: val_accuracy did not improve from 0.81000
# 38/38 [==============================] - 21s 548ms/step - loss: 0.2098 - accuracy: 0.9383 - val_loss: 0.5951 - val_accuracy: 0.7900
# Epoch 9/20
# 38/38 [==============================] - ETA: 0s - loss: 0.1803 - accuracy: 0.9483
# Epoch 9: val_accuracy did not improve from 0.81000
# 38/38 [==============================] - 21s 546ms/step - loss: 0.1803 - accuracy: 0.9483 - val_loss: 0.6511 - val_accuracy: 0.7900
# Epoch 10/20
# 38/38 [==============================] - ETA: 0s - loss: 0.1560 - accuracy: 0.9600
# Epoch 10: val_accuracy did not improve from 0.81000
# 38/38 [==============================] - 21s 547ms/step - loss: 0.1560 - accuracy: 0.9600 - val_loss: 0.7091 - val_accuracy: 0.7800
# Epoch 11/20
# 38/38 [==============================] - ETA: 0s - loss: 0.1491 - accuracy: 0.9600
# Epoch 11: val_accuracy improved from 0.81000 to 0.82000, saving model to /content/drive/MyDrive/project/final/ResNet_best.h5
# 38/38 [==============================] - 22s 593ms/step - loss: 0.1491 - accuracy: 0.9600 - val_loss: 0.6615 - val_accuracy: 0.8200
# Epoch 12/20
# 38/38 [==============================] - ETA: 0s - loss: 0.1150 - accuracy: 0.9783
# Epoch 12: val_accuracy did not improve from 0.82000
# 38/38 [==============================] - 23s 597ms/step - loss: 0.1150 - accuracy: 0.9783 - val_loss: 0.6291 - val_accuracy: 0.7700
# Epoch 13/20
# 38/38 [==============================] - ETA: 0s - loss: 0.1180 - accuracy: 0.9692
# Epoch 13: val_accuracy did not improve from 0.82000
# 38/38 [==============================] - 25s 644ms/step - loss: 0.1180 - accuracy: 0.9692 - val_loss: 0.6043 - val_accuracy: 0.7600
# Epoch 14/20
# 38/38 [==============================] - ETA: 0s - loss: 0.0934 - accuracy: 0.9842
# Epoch 14: val_accuracy did not improve from 0.82000
# 38/38 [==============================] - 21s 543ms/step - loss: 0.0934 - accuracy: 0.9842 - val_loss: 0.6302 - val_accuracy: 0.7900
# Epoch 15/20
# 38/38 [==============================] - ETA: 0s - loss: 0.0855 - accuracy: 0.9808
# Epoch 15: val_accuracy improved from 0.82000 to 0.83000, saving model to /content/drive/MyDrive/project/final/ResNet_best.h5
# 38/38 [==============================] - 24s 612ms/step - loss: 0.0855 - accuracy: 0.9808 - val_loss: 0.5813 - val_accuracy: 0.8300
# Epoch 16/20
# 38/38 [==============================] - ETA: 0s - loss: 0.0773 - accuracy: 0.9850
# Epoch 16: val_accuracy did not improve from 0.83000
# 38/38 [==============================] - 25s 668ms/step - loss: 0.0773 - accuracy: 0.9850 - val_loss: 0.8629 - val_accuracy: 0.7600
# Epoch 17/20
# 38/38 [==============================] - ETA: 0s - loss: 0.0870 - accuracy: 0.9800
# Epoch 17: val_accuracy did not improve from 0.83000
# 38/38 [==============================] - 22s 561ms/step - loss: 0.0870 - accuracy: 0.9800 - val_loss: 0.5125 - val_accuracy: 0.8300
# Epoch 18/20
# 38/38 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9892
# Epoch 18: val_accuracy did not improve from 0.83000
# 38/38 [==============================] - 21s 547ms/step - loss: 0.0641 - accuracy: 0.9892 - val_loss: 0.8072 - val_accuracy: 0.7100
# Epoch 19/20
# 38/38 [==============================] - ETA: 0s - loss: 0.0806 - accuracy: 0.9800
# Epoch 19: val_accuracy did not improve from 0.83000
# 38/38 [==============================] - 22s 571ms/step - loss: 0.0806 - accuracy: 0.9800 - val_loss: 0.6664 - val_accuracy: 0.8000
# Epoch 20/20
# 38/38 [==============================] - ETA: 0s - loss: 0.0596 - accuracy: 0.9892
# Epoch 20: val_accuracy did not improve from 0.83000
# 38/38 [==============================] - 23s 586ms/step - loss: 0.0596 - accuracy: 0.9892 - val_loss: 0.5737 - val_accuracy: 0.8200

# %%
# @title Test the Model
# @markdown > Test cells are currently commented for the sake of a smoother-running process
# @markdown # **Load the Model and Test it Against an Image**
# @markdown ## **Parameters**
img_path = '/content/apple-pie.png' # @param {type:"string"}

# @markdown ## **Process**
# @markdown 1. Load the model
# @markdown 2. Load the image and resize it
# @markdown 3. Process the image into an `img_array`
# @markdown 4. Predict using the loaded model
# @markdown 5. Get the index of the top prediction
# @markdown 6. Get the top prediction's labela dn probability
# @markdown 7. Display results

# loaded_model = load_model(args.resnet_model_path)

# img = Image.load_img(img_path, target_size=(224, 224))
# img_array = Image.img_to_array(img)
# img_array = np.expand_dims(img_array, axis=0)
# img_array = preprocess_input(img_array)

# predictions = loaded_model.predict(img_array)

# # Get the index of the top prediction
# top_index = predictions[0].argmax()

# # Get the top prediction label and probability
# top_prediction_label = class_labels[top_index]
# top_prediction_probability = predictions[0][top_index]

# print("Top Prediction:", top_prediction_label)
# print("Probability:", top_prediction_probability)

# %% [markdown]
# ## **XGBoost**

# %% [markdown]
# ### **Loading the Dataset and Preprocessing It**

# %%
# @markdown # **Downloaded the dataset .csv from drive**
# %cd /content/
# !gdown https://drive.google.com/uc?id=1yxoxiYNQW-tylsdBX-nrqSZbzfd_nZoV
# Out:
# /content
# Downloading...
# From: https://drive.google.com/uc?id=1yxoxiYNQW-tylsdBX-nrqSZbzfd_nZoV
# To: /content/food-to-allergies-optimized-dataset.csv
# 100% 201k/201k [00:00<00:00, 65.9MB/s]

# %%
# @markdown # **Load the Dataset and Preprocess it for XGBoost's Fine-Tuning**
# @markdown ## **Process**
# @markdown 1. Load the dataset
# @markdown 2. Check for missing values and handle them if found
# @markdown 3. Encode the `DISH` and `Allergy` columns separately
# @markdown 4. Define the features (`DISH`) and target (`Allergy`)
# @markdown 5. Split the dataset

df = pd.read_csv('/content/food-to-allergies-optimized-dataset.csv') # 1
df.dropna(inplace=True)  # 2. removes rows with missing values

# 3
dish_label_encoder = LabelEncoder()
df['DISH'] = dish_label_encoder.fit_transform(df['DISH'].astype(str))
allergy_label_encoder = LabelEncoder()
df['Allergy'] = allergy_label_encoder.fit_transform(df['Allergy'].astype(str))

# 4
X = df[['DISH']]
y = df['Allergy']

# 5
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=args.xgboost_split,
    random_state=args.xgboost_random_state
)

# %% [markdown]
# ### **Train, Evaluate, and Setup XGBoost for Implementation with YOLOv5 and ResNet50**

# %%
# @markdown # **Train and Evaluate XGBoost**
# Train the XGBoost model
model = xgb.XGBClassifier(
    n_estimators=args.xgboost_n_estimators,
    learning_rate=args.xgboost_learning_rate,
    max_depth=args.xgboost_max_depth
)
model.fit(X_train, y_train)

model.save_model(args.xgboost_model_path)

# Evaluate the model
predictions = model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 22.22%
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [15:23:21] WARNING: /workspace/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.
#   warnings.warn(smsg, UserWarning)

# %%
# @markdown # **Extract Ingredients and Allergies, and Construct a Sentence**
# @markdown By decoding the encoded result from the prediction with the corresponding decoder
# @markdown ## **Process**
# @markdown 1. `get_ingredients_and_allergies`
# @markdown   1. The first function takes in `dish_encoded`
# @markdown   and filters through the ddataframe to find the dish
# @markdown   2. It then gets the dish `ingredients` and `allergies` associated with it
# @markdown 2. construct_sentence: Takes in the data and builds the sentence from it
def get_ingredients_and_allergies(dish_encoded, df):
    dish_data = df[df['DISH'] == dish_encoded]
    ingredients = dish_data['Food'].tolist()
    allergies = dish_data['Allergy'].tolist()
    return ingredients, allergies

def construct_sentence(dish_encoded, df, dish_name, allergy_label_encoder):
    ingredients, allergy_codes = get_ingredients_and_allergies(dish_encoded, df)
    if not ingredients or not allergy_codes:
        return f"No allergy information available for {dish_name}."

    allergy_names = allergy_label_encoder.inverse_transform(allergy_codes)
    parts = [f"{ingredient} (which may cause {allergy})" for ingredient, allergy in zip(ingredients, allergy_names)]
    sentence = f"{dish_name.title()} contains " + ', '.join(parts) + '.'
    return sentence

# %% [markdown]
# ## **Integration of YOLOv5, ResNet50, and XGBoost**

# %%
# @markdown # **YOLOv5 and ResNet50 Automatic Run Funtions**
# @markdown **Short summary of the functions in this cell:**<br>
# @markdown `get_latest_exp_folder` Fetches the latest exp folder that contains the latest YOLOv5 result<br>
# @markdown `run_tolo_and_parse_results` is pretty self explanatory<br>
# @markdown `crop_image` cropped the original image to the bbox provided by YoOLOv5<br>
# @markdown `load_and_preprocess_for_resnet` also self explanatory<br>
# @markdown `predict_with_resnet` makes use of the fine-tuned resnet model to recognize which foods got detected by the YOLOv5 model

def get_latest_exp_folder(base_path):
    exp_folders = glob.glob(os.path.join(base_path, 'exp*'))
    if exp_folders:
        latest_folder = max(exp_folders, key=os.path.getmtime)
        print(latest_folder)
        return latest_folder
    else:
        return None

def run_yolo_and_parse_results(image_path, weights_path, confidence=0.25):
    print('Running YOLOv5 script')

    yolo_command = f"python {args.yolov5_path}yolov5/detect.py --weights {weights_path} --img 640 --conf {confidence} --source {image_path} --save-txt"
    print(yolo_command)
    # result = subprocess.run(yolo_command.split(), shell=True, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    # os.system(yolo_command)
    with subprocess.Popen(yolo_command.split(), stdout=subprocess.PIPE, stderr=subprocess.PIPE) as proc:
      stdout, stderr = proc.communicate()
      print("Output:", stdout.decode())
      print("Error:", stderr.decode())
    print('Fetching detected result')
    yolo_base_dir = f'{args.yolov5_path}yolov5/runs/detect'
    latest_exp_dir = get_latest_exp_folder(yolo_base_dir)

    print('Treating output')
    if latest_exp_dir:
        yolo_output_file = os.path.join(latest_exp_dir, 'labels', os.path.basename(image_path).replace('.png', '.txt'))
        detections = []
        if os.path.exists(yolo_output_file):
            with open(yolo_output_file, 'r') as file:
                for line in file:
                    detections.append(line.strip().split())
        return detections
    else:
        return []

def crop_image(image_path, bbox):
    with Image.open(image_path) as img:
        cropped_img = img.crop((bbox[0], bbox[1], bbox[2], bbox[3]))  # left, top, right, bottom
        return cropped_img

def load_and_preprocess_for_resnet(img):
    print('Preprocessing image for ResNet')
    # If img is a path, load the image
    if isinstance(img, str):
        img = keras_image.load_img(img, target_size=(224, 224))

    # If img is a PIL Image, resize it
    elif isinstance(img, Image.Image):
        img = img.resize((224, 224))

    img_array = keras_image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)
    return img_array


# Function to predict with ResNet
def predict_with_resnet(model_path, img_array):
  print('Feeding through ResNet')
  # Load ResNet model
  loaded_model = load_model(model_path)
  predictions = loaded_model.predict(img_array)

  # Get the top prediction
  top_index = predictions[0].argmax()
  top_prediction_label = class_labels[top_index]  # class_labels must be defined previously
  top_prediction_probability = predictions[0][top_index]

  return top_prediction_label, top_prediction_probability

# %%
# @markdown # **Run the Process From Start To Finish**
# @markdown YOLOv5 > ResNet50 > XGBoost > Final Result
# @markdown ## **Parameters**
image_test = '/content/drive/MyDrive/project/final/apple-pie.png' # @param {type:"string"}
yolo_weights = '/content/drive/MyDrive/project/final/yolov5/runs/train/exp/weights/best.pt' # @param {type:"string"}

# @markdown ## **Process**
# @markdown 1. Run YOLOv5 and save its `detections`
# @markdown 2. Loops through `detections` and saves their coordinates adjusts them to the image dimensions
# @markdown 3. Cropps the image, preprocesses it, and runs it into the ResNet50 model
# @markdown 4. After the label is output from the ResNet50 model, it gets encoded and runs through XGBoost
# @markdown 5. XGBoost then outputs the ingredients and their associated allergies,
# @markdown   which then get processed and output in a easy-to-understand format

# Updated usage of YOLO and ResNet
detections = run_yolo_and_parse_results(image_test, yolo_weights)

for detection in detections:
    # Convert bbox coordinates from YOLO format
    # Assuming bbox is [class, x_center, y_center, width, height]
    x_center, y_center, width, height = map(float, detection[1:5])
    image_width, image_height = Image.open(image_test).size
    left = int((x_center - width / 2) * image_width)
    top = int((y_center - height / 2) * image_height)
    right = int((x_center + width / 2) * image_width)
    bottom = int((y_center + height / 2) * image_height)
    bbox = [left, top, right, bottom]

    cropped_img = crop_image(image_test, bbox)
    img_array = load_and_preprocess_for_resnet(cropped_img)
    label, probability = predict_with_resnet(args.resnet_model_path, img_array)
    print("Top Prediction:", label)
    print("Probability:", probability)

    new_dish = label
    try:
      # Load the XGBoost model
      xgboost_model = xgb.XGBClassifier()
      xgboost_model.load_model(args.xgboost_model_path)  # Ensure this is the correct path to your model file

      new_dish_encoded = dish_label_encoder.transform([new_dish.lower()])[0]
      predicted_allergy = xgboost_model.predict([[new_dish_encoded]])[0]
      detailed_info = construct_sentence(new_dish_encoded, df, new_dish, allergy_label_encoder)
      print(detailed_info)
    except ValueError as e:
        # Handle the case where the dish is not in the dataset
        print(f"The dish '{label}' is not available in the dataset.")
# Out:
# Running YOLOv5 script
# python /content/drive/MyDrive/project/final/yolov5/detect.py --weights /content/drive/MyDrive/project/final/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/project/final/apple-pie.png --save-txt
# Output:
# Error: detect: weights=['/content/drive/MyDrive/project/final/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/project/final/apple-pie.png, data=drive/MyDrive/project/final/yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=drive/MyDrive/project/final/yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-249-gf400bba Python-3.10.12 torch-2.1.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/project/final/apple-pie.png: 640x640 3 foods, 412.2ms
# Speed: 2.1ms pre-process, 412.2ms inference, 6.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to drive/MyDrive/project/final/yolov5/runs/detect/exp2
# 1 labels saved to drive/MyDrive/project/final/yolov5/runs/detect/exp2/labels
#
# Fetching detected result
# /content/drive/MyDrive/project/final/yolov5/runs/detect/exp2
# Treating output
# Preprocessing image for ResNet
# Feeding through ResNet
# 1/1 [==============================] - 2s 2s/step
# Top Prediction: edamame
# Probability: 0.7486906
# The dish 'edamame' is not available in the dataset.
# Preprocessing image for ResNet
# Feeding through ResNet
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7e0d0fc06c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step
# Top Prediction: apple pie
# Probability: 0.90357524
# Apple Pie contains Butter (which may cause Milk allergy / Lactose intolerance), Butter bean (which may cause Legume Allergy), Buttermilk (which may cause Milk allergy / Lactose intolerance), Sugar (which may cause Sugar Allergy / Intolerance), Sugar beet (which may cause Sugar Allergy / Intolerance), Sugarcane (which may cause Sugar Allergy / Intolerance), Apple (which may cause Oral Allergy Syndrome), Pineapple (which may cause Oral Allergy Syndrome), Chestnut (which may cause Nut Allergy), Ginkgo nut (which may cause Nut Allergy), Peanut (which may cause Peanut Allergy), Walnut (which may cause Nut Allergy).
# Preprocessing image for ResNet
# Feeding through ResNet
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7e0d12e81870> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step
# Top Prediction: ice cream
# Probability: 0.520703
# Ice Cream contains Buttermilk (which may cause Milk allergy / Lactose intolerance), Milk (which may cause Milk allergy / Lactose intolerance).
